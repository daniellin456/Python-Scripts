# %%
import numpy as np
import matplotlib.pyplot as plt
from plot_style import *
plot_style()

# %%
# Dens and Energy Table are already in Log Scale
nRho = 625
nEner = 1000
nTemp = 1000
nPres = 1000
RhoMin = 1e-24
RhoMax = 10
Emin = 1e8 
Emax = 1e15
Tmin = 3.0
Tmax = 1e5
Pmin = 1e8
Pmax = 1e15

Const_kB = 1.3806e-16
Const_amu = 1.6605-24
mu = 2.31

# %%
Dens_Table = np.fromfile('../resources/Dens_Table.bin').reshape(1000,625).T
Eint_Table = np.fromfile('../resources/Ener_Table.bin').reshape(1000,625).T
DensEint2Temp_Table = np.fromfile('../resources/DensEint2Temp_Table.bin').reshape(1000,625).T
DensEint2Cs_Table = np.fromfile('../resources/DensEint2Cs_Table.bin').reshape(1000,625).T
DensEint2Pres_Table = np.fromfile('../resources/DensEint2Pres_Table.bin').reshape(1000,625).T
DensTemp2Eint_Table = np.fromfile('../resources/DensTemp2Eint_Table.bin').reshape(1000,625).T
DensPres2Eint_Table = np.fromfile('../resources/DensPres2Eint_Table.bin').reshape(1000,625).T
Fill_DensEint2Pres_Table = np.fromfile('../resources/Fill_DensEint2Pres_Table.bin').reshape(1000, 625).T
Fill_DensEint2Temp_Table = np.fromfile('../resources/Fill_DensEint2Temp_Table.bin').reshape(1000, 625).T
Fill_DensEint2Cs_Table = np.fromfile('../resources/Fill_DensEint2Cs_Table.bin').reshape(1000, 625).T

# %%
plt.figure(figsize=(8,6))
plt.title('Dens_Table')
plt.imshow(Dens_Table, origin = 'lower')
plt.colorbar()

# %%
plt.figure(figsize=(8,6))
plt.title('Eint_Table')
plt.imshow(Eint_Table, origin = 'lower')
plt.colorbar()

# %%
plt.figure(figsize=(20,6))

plt.subplot(1, 2, 1)
plt.title('DensEint2Temp_Table')
plt.imshow( np.log10(DensEint2Temp_Table), origin = 'lower')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.title('Fill_DensEint2Temp_Table')
plt.imshow( np.log10(Fill_DensEint2Temp_Table), origin = 'lower')
plt.colorbar()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log10
#   """
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log10
#   # Remove the CWD from sys.path while we load stuff.

# %%
plt.figure(figsize=(20,6))

plt.subplot(1, 2, 1)
plt.title('DensEint2Cs_Table')
plt.imshow( np.log10(DensEint2Cs_Table), origin = 'lower')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.title('Fill_DensEint2Cs_Table')
plt.imshow( np.log10(Fill_DensEint2Cs_Table), origin = 'lower')
plt.colorbar()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log10
#   """
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log10
#   # Remove the CWD from sys.path while we load stuff.

# %%
plt.figure(figsize=(20,6))

plt.subplot(1, 2, 1)
plt.title('DensEint2Pres_Table')
plt.imshow( np.log10(DensEint2Pres_Table), origin = 'lower')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.title('Fill_DensEint2Pres_Table')
plt.imshow( np.log10(Fill_DensEint2Pres_Table), origin = 'lower')
plt.colorbar()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log10
#   """

# %%
plt.figure(figsize=(8,6))
plt.title('DensTemp2Eint_Table')
plt.imshow( np.log10(DensTemp2Eint_Table), origin = 'lower')
plt.colorbar()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(8,6))
plt.title('DensPres2Eint_Table')
plt.imshow( np.log10(DensPres2Eint_Table), origin = 'lower')
plt.colorbar()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until
