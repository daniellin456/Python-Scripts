# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from plot_style import *
plot_style()

# %%
ramses_equilibrium_temp_data = {'nH': [1.00000000e-02, 1.84206997e-02, 3.39322177e-02, 6.25055193e-02,
                                       1.15139540e-01, 2.12095089e-01, 3.90693994e-01, 7.19685673e-01,
                                       1.32571137e+00, 2.44205309e+00, 4.49843267e+00, 8.28642773e+00,
                                       1.52641797e+01, 2.81176870e+01, 5.17947468e+01, 9.54095476e+01,
                                       1.75751062e+02, 3.23745754e+02, 5.96362332e+02, 1.09854114e+03,
                                       2.02358965e+03, 3.72759372e+03, 6.86648845e+03, 1.26485522e+04,
                                       2.32995181e+04, 4.29193426e+04, 7.90604321e+04, 1.45634848e+05,
                                       2.68269580e+05, 4.94171336e+05, 9.10298178e+05, 1.67683294e+06,
                                       3.08884360e+06, 5.68986603e+06, 1.04811313e+07, 1.93069773e+07,
                                       3.55648031e+07, 6.55128557e+07, 1.20679264e+08, 2.22299648e+08,
                                       4.09491506e+08, 7.54312006e+08, 1.38949549e+09, 2.55954792e+09,
                                       4.71486636e+09, 8.68511374e+09, 1.59985872e+10, 2.94705170e+10,
                                       5.42867544e+10, 1.00000000e+11], 
                                'T':[  8286.427728546843, 8286.427728546843, 8286.427728546843, 8286.427728546843, 
                                       8286.427728546843, 8286.427728546843, 8286.427728546843, 6866.488450042998, 
                                       2682.6957952797247, 719.6856730011514, 281.1768697974228, 132.57113655901082, 
                                       91.02981779915217, 62.505519252739695, 42.91934260128776, 35.564803062231285, 
                                       29.4705170255181, 24.42053094548651, 24.42053094548651, 20.235896477251565, 
                                       16.768329368110074, 16.768329368110074, 13.894954943731374, 13.894954943731374, 
                                       11.513953993264469, 11.513953993264469, 9.54095476349994, 9.54095476349994, 
                                       9.54095476349994, 7.906043210907698, 7.906043210907698, 7.906043210907698, 
                                       7.906043210907698, 6.551285568595508, 6.551285568595508, 6.551285568595508, 
                                       6.551285568595508, 5.428675439323859, 5.428675439323859, 5.428675439323859, 
                                       5.428675439323859, 5.428675439323859, 4.498432668969445, 4.498432668969445, 
                                       4.498432668969445, 4.498432668969445, 4.498432668969445, 4.498432668969445, 
                                       3.72759372031494, 3.72759372031494]}
ramses_equilibrium_temp_df = pd.DataFrame( data = ramses_equilibrium_temp_data )
ramses_equilibrium_temp_array = ramses_equilibrium_temp_df.to_numpy().T

# %%
Boland_et_al_1984_data = { 'nH': [50, 170, 250, 450, 890, 3e3, 1.3e4, 4.4e4, 7.3e4], 'T': [44, 39, 33, 29, 25, 20, 13.3, 10.4, 10.5] }
Boland_et_al_1984_df = pd.DataFrame( data = Boland_et_al_1984_data )
Boland_et_al_1984_data_array = Boland_et_al_1984_df.to_numpy().T
Boland_et_al_1984_data_array
# Out:
# array([[5.00e+01, 1.70e+02, 2.50e+02, 4.50e+02, 8.90e+02, 3.00e+03,
#         1.30e+04, 4.40e+04, 7.30e+04],
#        [4.40e+01, 3.90e+01, 3.30e+01, 2.90e+01, 2.50e+01, 2.00e+01,
#         1.33e+01, 1.04e+01, 1.05e+01]])

# %%
Larson_1973_data = {'log_rho': [-22, -21, -20, -19, -18, -17, -16, -15, -14, -13, -12], 'T':[50.6, 25.4, 15.8, 8.4, 5.1, 5.4, 6.4, 7.5, 9.1, 11.0, 13.3] }
Larson_1973_df = pd.DataFrame( data = Larson_1973_data )
Larson_1973_df_data_array = Larson_1973_df.to_numpy().T
Larson_1973_df_data_array
# Out:
# array([[-22. , -21. , -20. , -19. , -18. , -17. , -16. , -15. , -14. ,
#         -13. , -12. ],
#        [ 50.6,  25.4,  15.8,   8.4,   5.1,   5.4,   6.4,   7.5,   9.1,
#          11. ,  13.3]])

# %%
Myers_1978_data = {'nH': [1.5e-2, 3.6e-1, 3.5e1, 2.1e1, 3.3e3, 2.7e3, 7.8e3, 6.8e3, 8.8e2], 'T': [4.4e5, 4.5e3, 1.3e2, 4.1e2, 3.2e1, 1.0e1, 3.2e1, 1.3e1, 6.4e3]}
Myers_1978_df = pd.DataFrame( data = Myers_1978_data )
Myers_1978_data_array = Myers_1978_df.to_numpy().T
Myers_1978_data_array
# Out:
# array([[1.5e-02, 3.6e-01, 3.5e+01, 2.1e+01, 3.3e+03, 2.7e+03, 7.8e+03,
#         6.8e+03, 8.8e+02],
#        [4.4e+05, 4.5e+03, 1.3e+02, 4.1e+02, 3.2e+01, 1.0e+01, 3.2e+01,
#         1.3e+01, 6.4e+03]])

# %%
nH = np.logspace( 1, 6, 100 )
Av = 1
T = 163 / ( 2.5 + np.log( nH ) - np.log( 1 + 250 * np.exp( -1.2 * Av ) ) )
Tarafdaar_et_al_1985_data_array = np.vstack( (nH, T) )

# %%
plt.figure( figsize=(10,8) )
plt.plot( ramses_equilibrium_temp_array[0], ramses_equilibrium_temp_array[1], linestyle='-', linewidth = 5, label='Ramses Equilibrium Temp' )
plt.plot( Tarafdaar_et_al_1985_data_array[0], Tarafdaar_et_al_1985_data_array[1], linestyle='-', linewidth=5, label='Tarafdar et al.(1985)' )
plt.plot( 10**Larson_1973_df_data_array[0] / 1.66e-24, Larson_1973_df_data_array[1], linestyle='-.', linewidth = 5, label='Larson(1973)')
plt.plot( Boland_et_al_1984_data_array[0], Boland_et_al_1984_data_array[1], linestyle='--', linewidth = 5, label='Boland & de Jong(1984)' )
plt.scatter( Myers_1978_data_array[0], Myers_1978_data_array[1], s = 50, c='r', label='Myers(1978)' )
plt.xscale('log')
plt.yscale('log')
plt.xlim(10**-0.5, 10**6.5)
plt.ylim(10**-0.5, 10**4.5)
plt.xlabel(r'$log \; n(H_2) (cm^{-3})$')
plt.ylabel(r'$log \; T(K)$')
plt.legend()
plt.savefig('Larson_1985_Fig2.png', dpi=600)
